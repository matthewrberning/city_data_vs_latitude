# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#author: Matthew Berning

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
# import API_key - doesnot work

api_key = "1aff235fd4a4d47c690d9e50d53b2a44"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# city count
x = 1



#empty list
city_data_list = []

print("Beginning Data Retrieval")
print("------------------------")

#loop
for i, city in enumerate(cities):
    
    endpoint_url = url + '&q=' + city
    
    print("Processsing Record " + str(x) + " | " + city)
    
    x=x+1
    
    try:
        city_endpoint_json = requests.get(endpoint_url).json()
        
        cloudiness = city_endpoint_json["clouds"]["all"]
        country_of_city = city_endpoint_json["sys"]["country"]
        date = city_endpoint_json["dt"]
        humidity = city_endpoint_json["main"]["humidity"]
        latitude = city_endpoint_json["coord"]["lat"]
        longitude = city_endpoint_json["coord"]["lon"]
        maximum_temp = city_endpoint_json["main"]["temp_max"]
        wind_speed = city_endpoint_json["wind"]["speed"]
        
        
        city_data_list.append({"City": city,
                              "Cloudiness": cloudiness,
                              "Country": country_of_city,
                              "Date": date,
                              "Humidity": humidity,
                              "Lat": latitude,
                              "Lng": longitude,
                              "Max_Temp": maximum_temp,
                              "Wind_Speed": wind_speed})
  
    except:
        print("CITY NOT FOUND - SKIPPED")

print("**********done**********")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processsing Record 1 | rikitea
# Processsing Record 2 | bandarbeyla
# Processsing Record 3 | isangel
# Processsing Record 4 | georgetown
# Processsing Record 5 | kavaratti
# Processsing Record 6 | hobart
# Processsing Record 7 | hasaki
# Processsing Record 8 | castro
# Processsing Record 9 | chuy
# Processsing Record 10 | mogadishu
# Processsing Record 11 | butaritari
# Processsing Record 12 | dunedin
# Processsing Record 13 | amapa
# Processsing Record 14 | udachnyy
# Processsing Record 15 | pochutla
# Processsing Record 16 | gravdal
# Processsing Record 17 | ndouci
# CITY NOT FOUND - SKIPPED
# Processsing Record 18 | ribeira grande
# Processsing Record 19 | tarudant
# CITY NOT FOUND - SKIPPED
# Processsing Record 20 | noumea
# Processsing Record 21 | yellowknife
# Processsing Record 22 | praia da vitoria
# Processsing Record 23 | igrim
# Processsing Record 24 | nara
# Processsing Record 25 | tilichiki
# ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#test

city_data_list
# Out:
# [{'City': 'rikitea',
#   'Cloudiness': 24,
#   'Country': 'PF',
#   'Date': 1550726669,
#   'Humidity': 100,
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max_Temp': 78.35,
#   'Wind_Speed': 4.27},
#  {'City': 'bandarbeyla',
#   'Cloudiness': 92,
#   'Country': 'SO',
#   'Date': 1550726669,
#   'Humidity': 100,
#   'Lat': 9.49,
#   'Lng': 50.81,
#   'Max_Temp': 77.41,
#   'Wind_Speed': 12.66},
#  {'City': 'isangel',
#   'Cloudiness': 68,
#   'Country': 'VU',
#   'Date': 1550726669,
#   'Humidity': 94,
#   'Lat': -19.55,
#   'Lng': 169.27,
#   'Max_Temp': 83.62,
#   'Wind_Speed': 19.82},
#  {'City': 'georgetown',
#   'Cloudiness': 75,
#   'Country': 'GY',
#   'Date': 1550725200,
#   'Humidity': 94,
#   'Lat': 6.8,
#   'Lng': -58.16,
#   'Max_Temp': 75.2,
#   'Wind_Speed': 4.7},
#  {'City': 'kavaratti',
#   'Cloudiness': 12,
#   'Country': 'IN',
#   'Date': 1550726670,
#   'Humidity': 100,
#   'Lat': 10.57,
#   'Lng': 72.64,
#   'Max_Temp': 82.49,
#   'Wind_Speed': 10.42},
# ...

# %%
city_data_df = pd.DataFrame(city_data_list)

city_data_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      rikitea          24      PF  1550726669       100 -23.12 -134.97
# 1  bandarbeyla          92      SO  1550726669       100   9.49   50.81
# 2      isangel          68      VU  1550726669        94 -19.55  169.27
# 3   georgetown          75      GY  1550725200        94   6.80  -58.16
# 4    kavaratti          12      IN  1550726670       100  10.57   72.64
#
#    Max_Temp  Wind_Speed
# 0     78.35        4.27
# 1     77.41       12.66
# 2     83.62       19.82
# 3     75.20        4.70
# 4     82.49       10.42

# %%
city_data_df.count()
# Out:
# City          538
# Cloudiness    538
# Country       538
# Date          538
# Humidity      538
# Lat           538
# Lng           538
# Max_Temp      538
# Wind_Speed    538
# dtype: int64

# %%
#graph latitude vs. temperature

plt.scatter(city_data_df["Lat"], 
            city_data_df["Max_Temp"],
            edgecolor="black", color="#6495ED", alpha=0.9, linewidths=0.5, marker="o", label="Cities")


plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.title("City Latitude vs. Max Temperature (Feb. 2019)")
#change sixe of output figure
plt.rcParams["figure.figsize"] = [10,8]
#push out png
plt.savefig("figures/lat_vs_temp.png")



#test
plt.show()

# %%
#graph latitude vs. humidity

plt.scatter(city_data_df["Lat"], 
            city_data_df["Humidity"],
            edgecolor="black", color="#6495ED", alpha=0.9, linewidths=0.5, marker="o", label="Cities")


plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.title("City Latitude vs. Humidity (Feb. 2019)")
#change sixe of output figure
plt.rcParams["figure.figsize"] = [10,8]

#push out png
plt.savefig("figures/lat_vs_humidity.png")
#test
plt.show()

# %%
#graph latitude vs. Cloudiness

plt.scatter(city_data_df["Lat"], 
            city_data_df["Cloudiness"],
            edgecolor="black", color="#6495ED", alpha=0.9, linewidths=0.5, marker="o", label="Cities")


plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.title("City Latitude vs. Cloudiness (Feb. 2019)")
#change sixe of output figure
plt.rcParams["figure.figsize"] = [10,8]
#push out png
plt.savefig("figures/lat_vs_clouds.png")

#test
plt.show()

# %%
#graph latitude vs. Cloudiness

plt.scatter(city_data_df["Lat"], 
            city_data_df["Wind_Speed"],
            edgecolor="black", color="#6495ED", alpha=0.9, linewidths=0.5, marker="o", label="Cities")


plt.ylabel("Wind Speed (MPH)")
plt.xlabel("Latitude")
plt.grid(True)
plt.title("City Latitude vs. Wind Speed (Feb. 2019)")


#change sixe of output figure
plt.rcParams["figure.figsize"] = [10,8]
#push out png
plt.savefig("figures/lat_vs_wind.png")

#test
plt.show()
